# %% [markdown]
# # Generating Predictions
#
# Using the Logistic Regression model that we chose in the Selecting a Model notebook, we will create predictions for the 2021 NCAA Tournament.

# %%
# Import packages
import sys
sys.path.append('../')

import pandas as pd
from sklearn.linear_model import LogisticRegression
import collegebasketball as cbb

import warnings
warnings.filterwarnings('ignore')

cbb.__version__
# Out:
# '2023'

# %% [markdown]
# ## Train the Model
#
# Using the same method as before, we will train the model. To understand how I arrived at this model, please look at the Selecting a Model notebook for more information.
#
# However, there is one major difference in how we will train the model this time. Before, we split the data into training and testing sets, but since we are predicting for new games, we will use all of the training data to train the model.

# %%
# Load the csv files that contain the scores/kenpom data
path = '../Data/Training/training.csv'
train = pd.read_csv(path)

# Get a sense for the size of each data set
print('Length of training data: {}'.format(len(train)))
# Out:
# Length of training data: 16239

# %%
train.head(3)
# Out:
#        Favored        Underdog  Year Tournament  Label  Win_Loss_Fav  \
# 0          UNC  William & Mary  2010        NIT      0      0.540541
# 1  Wake Forest             UNC  2010        NaN      0      0.645161
# 2          UNC          Nevada  2010        NaN      0      0.540541
#
#    Win_Loss  AdjEM_Fav  AdjEM  AdjO_Fav  ...  FT%_opp_Fav  FT%_opp    AST_Fav  \
# 0  0.666667      13.39   6.58     107.4  ...        0.699    0.681  15.594595
# 1  0.540541      14.12  13.39     107.1  ...        0.687    0.699  11.903226
# 2  0.617647      13.39  10.20     107.4  ...        0.699    0.713  15.594595
#
#          AST  AST_opp_Fav    AST_opp   BLK_Fav       BLK  BLK_opp_Fav  \
# 0  14.030303    14.378378  13.151515  5.675676  2.545455     4.486486
# 1  15.594595    11.419355  14.378378  5.225806  5.675676     3.903226
# 2  14.117647    14.378378  15.029412  5.675676  4.382353     4.486486
#
#     BLK_opp
# 0  3.333333
# 1  4.486486
# 2  2.588235
#
# [3 rows x 55 columns]

# %%
# Get feature names
exclude = ['Favored', 'Underdog', 'Year', 'Tournament', 'Label']

features = list(train.columns)
for col in exclude:
    features.remove(col)

# %%
# Train the classifier
log = LogisticRegression(penalty='l2', C=10, solver='liblinear', random_state=77)
log.fit(train[features], train[['Label']])
# Out:
# LogisticRegression(C=10, random_state=77, solver='liblinear')

# %% [markdown]
# ## Get Input Data for this Year
#
# Next, we'll need to get the input data for this year so we can use it to predict game results for tournament games. We'll retrieve data from each source for this year, clean the data and combine it into a single data set.

# %%
year = 2023
stats_path = '../Data/SportsReference/' + str(year) + '_stats.csv'
# stats = cbb.load_stats_dataframe(year=year, csv_file_path=stats_path)
stats = pd.read_csv(stats_path)
stats = cbb.update_basic(stats.rename(index=str, columns={'School': 'Team'}))

# Fix absolute stats to be per game
cols_to_fix = ['3PA', '3PA_opp',  'AST', 'AST_opp', 'BLK', 'BLK_opp']
for c in cols_to_fix:
    stats[c] = stats[c] / stats['G']

stats[stats['Team'] == 'Marquette']
# Out:
#           Team   G    SRS   SOS   Tm.  Opp.    MP  FG_opp  FGA_opp  FG%_opp  \
# 159  Marquette  34  17.23  7.87  2718  2400  1380     872     1960    0.445
#
#      ...   FT  FTA    FT%  ORB   TRB        AST  STL       BLK  TOV   PF
# 159  ...  403  559  0.721  303  1084  17.588235  320  3.147059  365  553
#
# [1 rows x 39 columns]

# %%
kp_path = '../Data/Kenpom/' + str(year) + '_kenpom.csv'
# kenpom = cbb.load_kenpom_dataframe(year=year, csv_file_path=kp_path)
kenpom = pd.read_csv(kp_path)
kenpom = cbb.update_kenpom(kenpom)
kenpom[kenpom['Team'] == 'Marquette']
# Out:
#     Rank       Team  Seed Conf  Wins  Losses  AdjEM   AdjO  AdjO Rank  AdjD  \
# 11    12  Marquette   2.0   BE    28       6  21.83  119.3          8  97.5
#
#     ...   Luck  Luck Rank  OppAdjEM  OppAdjEM Rank   OppO  OppO Rank   OppD  \
# 11  ...  0.014        150      8.67             39  109.5         35  100.9
#
#     OppD Rank  NCSOS AdjEM  NCSOS AdjEM Rank
# 11         51        -1.14               196
#
# [1 rows x 23 columns]

# %%
TRank_path = '../Data/TRank/' + str(year) + '_TRank.csv'
# TRank = cbb.load_TRank_dataframe(year=year, csv_file_path=TRank_path)
TRank = pd.read_csv(TRank_path)
TRank = cbb.update_TRank(TRank)
TRank[TRank['Team'] == 'Marquette']
# Out:
#     Rk       Team Conf   G  Wins  Losses  AdjOE  AdjOE Rank  AdjDE  \
# 12  13  Marquette   BE  34    28       6  119.0           9   97.1
#
#     AdjDE Rank  ...  2P%D  2P%D Rank   3P%  3P% Rank  3P%D  3P%D Rank  Adj T.  \
# 12          44  ...  50.0        169  34.8       134  35.2        253    68.6
#
#     Adj T. Rank  WAB  WAB Rank
# 12          115  7.5         8
#
# [1 rows x 40 columns]

# %%
# Merge the data from each source (and drop columns that are repeats)
team_stats = pd.merge(kenpom, TRank.drop(['Conf', 'Wins', 'Losses'], axis=1), on='Team', sort=False)
team_stats = pd.merge(team_stats, stats.drop(['G', 'ORB', '3P%', 'ORB'], axis=1), on='Team', sort=False)
team_stats[team_stats['Team'] == 'Marquette']
# Out:
#     Rank       Team  Seed Conf  Wins  Losses  AdjEM   AdjO  AdjO Rank  AdjD  \
# 11    12  Marquette   2.0   BE    28       6  21.83  119.3          8  97.5
#
#     ...        3PA   FT  FTA    FT%   TRB        AST  STL       BLK  TOV   PF
# 11  ...  25.441176  403  559  0.721  1084  17.588235  320  3.147059  365  553
#
# [1 rows x 94 columns]

# %%
# Load Tournament games
games_path = '../Data/Tourney/{}.csv'.format(year)
games = pd.read_csv(games_path)
games.head(3)
# Out:
#               Home                      Away
# 0          Alabama  Texas A&M-Corpus Christi
# 1         Maryland             West Virginia
# 2  San Diego State     College of Charleston

# %%
# Join the team data with the game data
data = pd.merge(games, team_stats, left_on='Home', right_on='Team', sort=False)
data = pd.merge(data, team_stats, left_on='Away', right_on='Team', suffixes=('_Home', '_Away'), sort=False)
data.insert(0, 'Year', year)
data.insert(3, 'Tournament', 'NCAA Tournament')
data.head(3)
# Out:
#    Year             Home                      Away       Tournament  \
# 0  2023          Alabama  Texas A&M-Corpus Christi  NCAA Tournament
# 1  2023         Maryland             West Virginia  NCAA Tournament
# 2  2023  San Diego State     College of Charleston  NCAA Tournament
#
#    Rank_Home        Team_Home  Seed_Home Conf_Home  Wins_Home  Losses_Home  \
# 0          3          Alabama        1.0       SEC         29            5
# 1         22         Maryland        8.0       B10         21           12
# 2         14  San Diego State        5.0       MWC         27            6
#
#    ...   3PA_Away  FT_Away  FTA_Away  FT%_Away  TRB_Away   AST_Away  STL_Away  \
# 0  ...  21.058824      577       731     0.789      1262  15.529412       292
# 1  ...  20.878788      558       753     0.741      1117  13.181818       221
# 2  ...  30.205882      522       704     0.741      1377  13.794118       250
#
#    BLK_Away  TOV_Away  PF_Away
# 0  1.676471       442      647
# 1  3.090909       428      608
# 2  3.147059       408      572
#
# [3 rows x 192 columns]

# %% [markdown]
# ## Predict Games Using the Classifier
#
# Now that we have a trained model and data for the tournament games this year, we can use it to predict games in the 2021 NCAA Tournament.

# %%
# Make Predictions
predictions = cbb.predict(log, data, features)
predictions.to_csv('../Data/predictions/predictions_2023.csv', index=False)
predictions['Upset'] = predictions['Underdog'] == predictions['Predicted Winner']

# %%
# First Round
predictions.iloc[0:32,:]
# Out:
#             Favored                  Underdog  Predicted Winner  \
# 0           Alabama  Texas A&M-Corpus Christi           Alabama
# 1     West Virginia                  Maryland     West Virginia
# 2   San Diego State     College of Charleston   San Diego State
# 3          Virginia                    Furman          Virginia
# 4         Creighton                  NC State         Creighton
# 5            Baylor                      UCSB            Baylor
# 6        Utah State                  Missouri          Missouri
# 7           Arizona                 Princeton           Arizona
# 8            Purdue       Fairleigh Dickinson            Purdue
# 9           Memphis          Florida Atlantic  Florida Atlantic
# 10             Duke              Oral Roberts              Duke
# 11        Tennessee                 Louisiana         Louisiana
# 12         Kentucky                Providence        Providence
# 13     Kansas State             Montana State      Kansas State
# 14   Michigan State                       USC    Michigan State
# 15        Marquette                   Vermont         Marquette
# 16          Houston         Northern Kentucky           Houston
# 17           Auburn                      Iowa            Auburn
# 18       Miami (FL)                     Drake             Drake
# 19          Indiana                Kent State           Indiana
# 20       Iowa State                      Pitt        Iowa State
# 21           Xavier            Kennesaw State            Xavier
# 22        Texas A&M                Penn State         Texas A&M
# 23            Texas                   Colgate             Texas
# 24           Kansas                    Howard            Kansas
# 25         Arkansas                  Illinois          Illinois
# 26     Saint Mary's                       VCU      Saint Mary's
# 27            UConn                      Iona             UConn
# 28              TCU             Arizona State     Arizona State
# 29          Gonzaga              Grand Canyon           Gonzaga
# 30      Boise State              Northwestern      Northwestern
# 31             UCLA             UNC Asheville              UCLA
#
#     Probabilities  Upset
# 0        0.008773  False
# 1        0.486833  False
# 2        0.148697  False
# 3        0.160343  False
# 4        0.370027  False
# 5        0.111844  False
# 6        0.519677   True
# 7        0.061443  False
# 8        0.002217  False
# 9        0.500202   True
# 10       0.229827  False
# 11       0.204666   True
# 12       0.441540   True
# 13       0.106827  False
# 14       0.469729  False
# 15       0.049512  False
# 16       0.029578  False
# 17       0.458786  False
# 18       0.278290   True
# 19       0.192164  False
# 20       0.268431  False
# 21       0.122683  False
# 22       0.455092  False
# 23       0.026542  False
# 24       0.012285  False
# 25       0.519798   True
# 26       0.262915  False
# 27       0.094108  False
# 28       0.408864   True
# 29       0.087662  False
# 30       0.494130   True
# 31       0.042344  False

# %%
# Second Round
predictions.iloc[32:48,:]
# Out:
#             Favored          Underdog Predicted Winner  Probabilities  Upset
# 32          Alabama     West Virginia          Alabama       0.194988  False
# 33  San Diego State          Virginia  San Diego State       0.360758  False
# 34        Creighton            Baylor           Baylor       0.687204   True
# 35          Arizona          Missouri         Missouri       0.345528   True
# 36           Purdue  Florida Atlantic           Purdue       0.239604  False
# 37             Duke         Louisiana             Duke       0.197040  False
# 38     Kansas State        Providence       Providence       0.305677   True
# 39        Marquette    Michigan State   Michigan State       0.330760   True
# 40          Houston            Auburn          Houston       0.238223  False
# 41          Indiana             Drake          Indiana       0.187885  False
# 42           Xavier        Iowa State       Iowa State       0.460507   True
# 43            Texas         Texas A&M            Texas       0.322248  False
# 44           Kansas          Illinois           Kansas       0.161356  False
# 45            UConn      Saint Mary's     Saint Mary's       0.421827   True
# 46          Gonzaga     Arizona State          Gonzaga       0.265133  False
# 47             UCLA      Northwestern             UCLA       0.220668  False

# %%
# Later Rounds
predictions.iloc[48:,:]
# Out:
#            Favored         Underdog Predicted Winner  Probabilities  Upset
# 48         Alabama  San Diego State          Alabama       0.316853  False
# 49          Baylor         Missouri         Missouri       0.428894   True
# 50          Purdue             Duke           Purdue       0.278314  False
# 51  Michigan State       Providence       Providence       0.401160   True
# 52         Houston          Indiana          Indiana       0.340967   True
# 53           Texas       Iowa State            Texas       0.295410  False
# 54          Kansas     Saint Mary's           Kansas       0.241350  False
# 55            UCLA          Gonzaga          Gonzaga       0.380177   True
# 56         Alabama         Missouri          Alabama       0.235016  False
# 57          Purdue       Providence           Purdue       0.174273  False
# 58           Texas          Indiana            Texas       0.298134  False
# 59         Gonzaga           Kansas           Kansas       0.668796   True
# 60         Alabama           Purdue          Alabama       0.439003  False
# 61           Texas           Kansas           Kansas       0.600334   True
# 62         Alabama           Kansas           Kansas       0.524805   True

# %% [markdown]
# Congratulations to all Kansas fans because the model has predicted the Jayhawks to repeat as the the 2023 NCAA Tournament Champion!
